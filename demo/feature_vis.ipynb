# %%
from mmcv import load
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

zs = load('../work_dirs/zs/zs_8_convnew.pkl')
zs_gcl = load('../work_dirs/zs/zs_8_convnew_gcl.pkl')

# %%
# Define the data and labels
data = [z for z in zs if z[1] in [7, 8, 9, 10, 11, 12]]

X = [x[0] for x in data]
y = [x[1] for x in data]

# Apply t-SNE to reduce the dimensionality to 2 dimensions
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# Plot the t-SNE visualization
plt.figure(figsize=(10, 8))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap=plt.cm.get_cmap("jet", 10))
plt.colorbar(ticks=range(10))
plt.title('t-SNE Visualization of 3 PC 2 PC2 Conv')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# /home/trungct/miniconda3/envs/pyskl/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /home/trungct/miniconda3/envs/pyskl/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
# Define the data and labels
data = [z for z in zs_gcl if z[1] in [7, 8, 9, 10, 11, 12]]

X = [x[0] for x in data]
y = [x[1] for x in data]

# Apply t-SNE to reduce the dimensionality to 2 dimensions
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# Plot the t-SNE visualization
plt.figure(figsize=(10, 8))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap=plt.cm.get_cmap("jet", 10))
plt.colorbar(ticks=range(10))
plt.title('t-SNE Visualization of 3 PC 2 PC2 Conv + GCL')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()
# Out:
# /home/trungct/miniconda3/envs/pyskl/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /home/trungct/miniconda3/envs/pyskl/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
